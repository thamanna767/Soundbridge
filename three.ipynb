# %% [markdown]
# Added Labels :gesture and emotional

# %%
from sklearn.preprocessing import MinMaxScaler


# Separate inputs and labels
X = df.drop(columns=["Gesture_Label", "Emotion_Label"])
y_gesture = df["Gesture_Label"]
y_emotion = df["Emotion_Label"]

# Create Min-Max scaler (0–1)
scaler = MinMaxScaler(feature_range=(0, 1))

# Apply normalization
X_scaled = scaler.fit_transform(X)


# Separate inputs and labels
X = df.drop(columns=["Gesture_Label", "Emotion_Label"])
y_gesture = df["Gesture_Label"]
y_emotion = df["Emotion_Label"]

# Create Min-Max scaler (0–1)
scaler = MinMaxScaler(feature_range=(0, 1))

# Apply normalization
X_scaled = scaler.fit_transform(X)


X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)


final_df = X_scaled_df.copy()
final_df["Gesture_Label"] = y_gesture.values
final_df["Emotion_Label"] = y_emotion.values


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y_gesture, test_size=0.2, random_state=42
)

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


import numpy as np
import pandas as pd

# Number of samples (simulation)
num_samples = 300

# -------------------------------
# Flex sensors (5 fingers)
# -------------------------------
flex_data = {
    "Flex_1": np.random.uniform(0, 90, num_samples),
    "Flex_2": np.random.uniform(0, 90, num_samples),
    "Flex_3": np.random.uniform(0, 90, num_samples),
    "Flex_4": np.random.uniform(0, 90, num_samples),
    "Flex_5": np.random.uniform(0, 90, num_samples),
}

# -------------------------------
# Pressure sensors (4 locations)
# -------------------------------
pressure_data = {
    "Press_Thumb": np.random.uniform(0, 100, num_samples),
    "Press_Index": np.random.uniform(0, 100, num_samples),
    "Press_Middle": np.random.uniform(0, 100, num_samples),
    "Press_Thenar": np.random.uniform(0, 100, num_samples),
}

# -------------------------------
# IMU accelerometer data
# -------------------------------
imu_sensor_data_dict = { # Renamed to avoid conflict
    "Acc_X": np.random.uniform(-2, 2, num_samples),
    "Acc_Y": np.random.uniform(-2, 2, num_samples),
    "Acc_Z": np.random.uniform(-2, 2, num_samples),
}

# -------------------------------
# Labels
# -------------------------------
labels = {
    "Gesture_Label": np.random.randint(0, 4, num_samples),   # 4 gestures
    "Emotion_Label": np.random.randint(0, 3, num_samples),   # 3 emotions
}

# -------------------------------
# Create DataFrame
# -------------------------------
df = pd.DataFrame({
    **flex_data,
    **pressure_data,
    **imu_sensor_data_dict, # Use the new name here
    **labels
})

# Check
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-80008525.py in <cell line: 0>()
#       3
#       4 # Separate inputs and labels
# ----> 5 X = df.drop(columns=["Gesture_Label", "Emotion_Label"])
#       6 y_gesture = df["Gesture_Label"]
#       7 y_emotion = df["Emotion_Label"]
#
# NameError: name 'df' is not defined

# %%
import numpy as np
import pandas as pd

# Number of samples (simulation)
num_samples = 300

# -------------------------------
# Flex sensors (5 fingers)
# -------------------------------
flex_data = {
    "Flex_1": np.random.uniform(0, 90, num_samples),
    "Flex_2": np.random.uniform(0, 90, num_samples),
    "Flex_3": np.random.uniform(0, 90, num_samples),
    "Flex_4": np.random.uniform(0, 90, num_samples),
    "Flex_5": np.random.uniform(0, 90, num_samples),
}

# -------------------------------
# Pressure sensors (4 locations)
# -------------------------------
pressure_data = {
    "Press_Thumb": np.random.uniform(0, 100, num_samples),
    "Press_Index": np.random.uniform(0, 100, num_samples),
    "Press_Middle": np.random.uniform(0, 100, num_samples),
    "Press_Thenar": np.random.uniform(0, 100, num_samples),
}

# -------------------------------
# IMU accelerometer data
# -------------------------------
imu_sensor_data_dict = { # Renamed to avoid conflict
    "Acc_X": np.random.uniform(-2, 2, num_samples),
    "Acc_Y": np.random.uniform(-2, 2, num_samples),
    "Acc_Z": np.random.uniform(-2, 2, num_samples),
}

# -------------------------------
# Labels
# -------------------------------
labels = {
    "Gesture_Label": np.random.randint(0, 4, num_samples),   # 4 gestures
    "Emotion_Label": np.random.randint(0, 3, num_samples),   # 3 emotions
}

# -------------------------------
# Create DataFrame
# -------------------------------
df = pd.DataFrame({
    **flex_data,
    **pressure_data,
    **imu_sensor_data_dict, # Use the new name here
    **labels
})

# Check
df.head()

from sklearn.preprocessing import MinMaxScaler


# Separate inputs and labels
X = df.drop(columns=["Gesture_Label", "Emotion_Label"])
y_gesture = df["Gesture_Label"]
y_emotion = df["Emotion_Label"]

# Create Min-Max scaler (0–1)
scaler = MinMaxScaler(feature_range=(0, 1))

# Apply normalization
X_scaled = scaler.fit_transform(X)


X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)


final_df = X_scaled_df.copy()
final_df["Gesture_Label"] = y_gesture.values
final_df["Emotion_Label"] = y_emotion.values


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y_gesture, test_size=0.2, random_state=42
)

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
