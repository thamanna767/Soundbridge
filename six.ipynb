# %% [markdown]
# 2 stage model training: lstm training

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import pandas as pd # Added import for pandas


if 'X' not in locals() or 'y_gesture' not in locals():
    print("Warning: X and y_gesture not found in environment. Using placeholder data.")
    # Create dummy data if X and y_gesture are not defined
    num_samples = 100
    num_features = 10
    num_classes_dummy = 3
    X = pd.DataFrame(np.random.rand(num_samples, num_features))
    y_gesture = pd.Series(np.random.randint(0, num_classes_dummy, num_samples))
X_lstm = X.values.reshape(X.shape[0], 1, X.shape[1])
y_labels = y_gesture.values

num_classes = len(np.unique(y_labels))
y_cat = to_categorical(y_labels, num_classes)

X_train, X_test, y_train, y_test = train_test_split(
    X_lstm, y_cat, test_size=0.2, random_state=42
)

# -----------------------------
# LSTM Model
# -----------------------------
model_gesture = Sequential([
    LSTM(64, return_sequences=True, input_shape=(X_lstm.shape[1], X_lstm.shape[2])),
    Dropout(0.3),
    LSTM(32),
    Dense(64, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model_gesture.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model_gesture.summary()

# -----------------------------
# Train
# -----------------------------
model_gesture.fit(
    X_train, y_train,
    epochs=30,
    batch_size=32,
    validation_data=(X_test, y_test)
)

# -----------------------------
# Save model
# -----------------------------
model_gesture.save("gesture_model_lstm.keras") # Added .keras extension
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 1, 64)          │        19,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,923 (132.51 KB)
#  Trainable params: 33,923 (132.51 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - accuracy: 0.3789 - loss: 1.0982 - val_accuracy: 0.3500 - val_loss: 1.0963
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3992 - loss: 1.0964 - val_accuracy: 0.3500 - val_loss: 1.0952
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4031 - loss: 1.0938 - val_accuracy: 0.3500 - val_loss: 1.0942
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4227 - loss: 1.0913 - val_accuracy: 0.3500 - val_loss: 1.0929
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4227 - loss: 1.0894 - val_accuracy: 0.3500 - val_loss: 1.0920
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4031 - loss: 1.0910 - val_accuracy: 0.3500 - val_loss: 1.0913
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3914 - loss: 1.0883 - val_accuracy: 0.3500 - val_loss: 1.0906
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3836 - loss: 1.0926 - val_accuracy: 0.3500 - val_loss: 1.0900
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4031 - loss: 1.0863 - val_accuracy: 0.3500 - val_loss: 1.0893
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4266 - loss: 1.0809 - val_accuracy: 0.3500 - val_loss: 1.0885
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4109 - loss: 1.0842 - val_accuracy: 0.3500 - val_loss: 1.0877
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3914 - loss: 1.0817 - val_accuracy: 0.3500 - val_loss: 1.0870
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4305 - loss: 1.0792 - val_accuracy: 0.3500 - val_loss: 1.0867
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4227 - loss: 1.0797 - val_accuracy: 0.3500 - val_loss: 1.0864
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4070 - loss: 1.0785 - val_accuracy: 0.3500 - val_loss: 1.0860
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4031 - loss: 1.0782 - val_accuracy: 0.3500 - val_loss: 1.0855
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4187 - loss: 1.0737 - val_accuracy: 0.3500 - val_loss: 1.0851
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3719 - loss: 1.0809 - val_accuracy: 0.3500 - val_loss: 1.0846
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4383 - loss: 1.0693 - val_accuracy: 0.3500 - val_loss: 1.0843
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3797 - loss: 1.0862 - val_accuracy: 0.3500 - val_loss: 1.0838
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3914 - loss: 1.0855 - val_accuracy: 0.3500 - val_loss: 1.0832
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3758 - loss: 1.0880 - val_accuracy: 0.3500 - val_loss: 1.0825
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3992 - loss: 1.0741 - val_accuracy: 0.3500 - val_loss: 1.0819
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4148 - loss: 1.0674 - val_accuracy: 0.3500 - val_loss: 1.0815
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4305 - loss: 1.0661 - val_accuracy: 0.3500 - val_loss: 1.0812
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3719 - loss: 1.0727 - val_accuracy: 0.3500 - val_loss: 1.0806
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4109 - loss: 1.0751 - val_accuracy: 0.3500 - val_loss: 1.0803
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4227 - loss: 1.0737 - val_accuracy: 0.3500 - val_loss: 1.0802
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4133 - loss: 1.0614 - val_accuracy: 0.3500 - val_loss: 1.0796
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4313 - loss: 1.0662 - val_accuracy: 0.3500 - val_loss: 1.0792
