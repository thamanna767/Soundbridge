# %% [markdown]
# 2 stage modelling:loading emotional feature extraction

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# -----------------------------
# Load emotion features
# -----------------------------
# Features: [gesture_intensity, pressure, emg...]
# X_emotion = np.load("emotion_features.npy") # Removed, using existing Xe_train/Xe_test
# y_emotion = np.load("emotion_labels.npy") # Removed, using existing ye_train/ye_test

# Normalize
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(Xe_train) # Use Xe_train from previous split
X_test_scaled = scaler.transform(Xe_test)   # Use Xe_test from previous split

# X_train, X_test, y_train, y_test = train_test_split(
#     X_emotion, y_emotion, test_size=0.2, random_state=42 # Removed, using existing splits
# )

# -----------------------------
# SVM Model
# -----------------------------
emotion_model = SVC(
    kernel='rbf',
    C=10,
    gamma='scale',
    probability=True
)

emotion_model.fit(X_train_scaled, ye_train) # Use scaled training features and existing labels

# -----------------------------
# Evaluation
# -----------------------------
y_pred = emotion_model.predict(X_test_scaled) # Use scaled testing features
print(classification_report(ye_test, y_pred)) # Use existing testing labels

# -----------------------------
# Save model
# -----------------------------
import joblib
joblib.dump(emotion_model, "emotion_model_svm.pkl")
joblib.dump(scaler, "emotion_scaler.pkl")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        39
#            2       1.00      1.00      1.00        32
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
# ['emotion_scaler.pkl']
